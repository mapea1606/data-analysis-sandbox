# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").appName("VerificacionPySpark").getOrCreate()
print("¡PySpark iniciado correctamente!")
spark.stop()
# Out:
# ¡PySpark iniciado correctamente!

# %%
# Detener la sesión de Spark
spark.stop()
print("SparkSession detenida. Recursos liberados.")
